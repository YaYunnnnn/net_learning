# %% [markdown]
# <a href="https://colab.research.google.com/github/YaYunnnnn/net_learning/blob/main/FinalReport_clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 安裝必要內容

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# !pip install textsum
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...

# %% [markdown]
# #google news節錄的安裝包

# %%
# !pip install GoogleNews
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 4.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# #文本總結的安裝包

# %%
#hugging face:https://reurl.cc/xLnXee
from textsum.summarize import Summarizer

model_name = "pszemraj/led-large-book-summary"
summarizer = Summarizer(
    model_name_or_path=model_name,  # you can use any Seq2Seq model on the Hub
    token_batch_length=4096,  # tokens to batch summarize at a time, up to 16384
)
# Out:
# WARNING:root:Since the GPL-licensed package `unidecode` is not installed, using Python's `unicodedata` package which yields worse results.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.84G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.32k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# ...

# %%
#type2:節錄雲端文件
#hugging face:https://reurl.cc/xLnXee
# 安裝必要的庫
# !pip install gspread textsum google-auth google-auth-oauthlib google-auth-httplib2

# 匯入所需的模組
import gspread
from google.colab import auth
from oauth2client.client import GoogleCredentials
from textsum.summarize import Summarizer

# %% [markdown]
# #節錄文字的必要安裝包

# %%
# !pip install spacy pytextrank
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 20.6 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# #情意分析的必要安裝包

# %%
# 匯入所需的模組
from collections import defaultdict

# %% [markdown]
# # 開放google授權

# %%
from google.colab import auth
auth.authenticate_user()

import google.auth
from google.auth.transport.requests import Request
from google.colab import auth
from oauth2client.client import GoogleCredentials
from gspread import authorize

creds, _ = google.auth.default()
gc = authorize(creds)

# %%
def df_to_sheets(df, spreadsheet_id, sheet_name):
  try:
    sh = gc.open_by_key(spreadsheet_id)
  except Exception as e:
    print(f"Error opening the Spreadsheet: {e}")
    return

  try:
    worksheet = sh.worksheet(sheet_name)
  except gspread.WorksheetNotFound:
    worksheet = sh.add_worksheet(title=sheet_name, rows="100", cols="20")

  worksheet.update([df.columns.values.tolist()] + df.values.tolist())

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

import pandas as pd
# read data and put it in a dataframe
# 在 google 工作表載入 gsheets
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1NEts6y1L2VQE6pBM7f4GRWeP0mdFQKanIJiFDPBcrRs/edit?usp=sharing')
# 從 gsheets 的工作表
sheets1 = gsheets.worksheet('作業5(導入)').get_all_values()

df = pd.DataFrame(sheets1[1:], columns=sheets1[0])

# %%
spreadsheet_id = '1Y09gfTxAWBuRAYCrSAL10dJwsWf9hdP9fmKHZA3mDkY'
sheet_name = '作業5(導入)'

def truncate_to_limit(cell_value, limit=10000):
  if len(cell_value) > limit:
    return cell_value[:limit] + '... [內容過長，已停止寫入]'
  else:
    return cell_value

# %% [markdown]
# #導入google sheet(不可動)

# %%
# 安裝必要的庫
# !pip install gspread textsum google-auth google-auth-oauthlib google-auth-httplib2 requests transformers gradio
# 匯入所需的模組
import gradio as gr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 9.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.3/316.3 kB 25.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 14.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 51.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 13.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.7 MB/s eta 0:00:00
# ...

# %%
import gspread
import pandas as pd
import gradio as gr
from oauth2client.service_account import ServiceAccountCredentials

# 讀取公開共享的 Google Sheets
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1NEts6y1L2VQE6pBM7f4GRWeP0mdFQKanIJiFDPBcrRs/edit?usp=sharing')
sheet_data = gsheets.worksheet('作業5(導入)').get_all_values()

# %% [markdown]
# #全文查詢

# %%
import gspread
import pandas as pd
import gradio as gr
from datetime import datetime
from GoogleNews import GoogleNews
from google.auth import default
import spacy
import pytextrank

# Authenticate with Google Sheets
creds, _ = default()
gc = gspread.authorize(creds)

# Initialize the connection to Google Sheets
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1NEts6y1L2VQE6pBM7f4GRWeP0mdFQKanIJiFDPBcrRs/edit?usp=sharing'
gsheets = gc.open_by_url(spreadsheet_url)
sheet_data = gsheets.worksheet('作業5(導入)').get_all_values()

# Convert the data to a DataFrame
df = pd.DataFrame(sheet_data[1:], columns=sheet_data[0])  # Skip the first header row

# Load spaCy and pytextrank
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("textrank")

def extract_keywords(text):
    doc = nlp(text)
    keywords = [phrase.text for phrase in doc._.phrases[:5]]  # Extract top 5 key phrases
    return ", ".join(keywords)

def fetch_news(query):
    googlenews = GoogleNews()
    googlenews.search(query)
    result = googlenews.result()

    news_list = []
    for item in result:
        title = item['title']
        date = item['date']
        desc = item['desc']
        link = item['link']
        keywords = extract_keywords(desc)
        news_list.append([title, date, desc, link, keywords])

    return news_list

def add_sheet(query, data):
    date_str = datetime.now().strftime('%Y-%m-%d')
    new_sheet_name = f"{query}&{date_str}"
    try:
        worksheet = gsheets.add_worksheet(title=new_sheet_name, rows=data.shape[0]+1, cols=data.shape[1])
        worksheet.update([data.columns.values.tolist()] + data.values.tolist())
    except gspread.exceptions.APIError as e:
        print(f"Error adding worksheet: {e}")

def display_data(query):
    if query:
        news_results = fetch_news(query)
        if news_results:
            filtered_df = pd.DataFrame(news_results, columns=['標題', '日期', '描述', '連結', '關鍵字'])
            add_sheet(query, filtered_df)
            return filtered_df
    return pd.DataFrame(columns=['標題', '日期', '描述', '連結', '關鍵字'])

with gr.Blocks() as demo:
    gr.Markdown("<h1 style='text-align: center;'>專題報告_與論節錄</h1>")

    with gr.TabItem("作業5"):
        gr.Markdown("請輸入您本次想要在 Google News 查閱的文章關鍵字")
        query_input = gr.Textbox(placeholder="請輸入關鍵字")
        display_button = gr.Button("送出")
        data_table = gr.DataFrame(label="資料表")

        # 設置按鈕點擊事件
        display_button.click(fn=display_data, inputs=query_input, outputs=data_table)

demo.launch()
# Out:
# /usr/local/lib/python3.10/dist-packages
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://25a3e59ec015bcc3d0.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://25a3e59ec015bcc3d0.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# #新增文本總結功能

# %%
import gspread
import pandas as pd
import gradio as gr
from datetime import datetime
from GoogleNews import GoogleNews
from google.auth import default
import spacy
import pytextrank
from transformers import pipeline

# Authenticate with Google Sheets
creds, _ = default()
gc = gspread.authorize(creds)

# Initialize the connection to Google Sheets
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1NEts6y1L2VQE6pBM7f4GRWeP0mdFQKanIJiFDPBcrRs/edit?usp=sharing'
gsheets = gc.open_by_url(spreadsheet_url)
sheet_data = gsheets.worksheet('作業5(導入)').get_all_values()

# Convert the data to a DataFrame
df = pd.DataFrame(sheet_data[1:], columns=sheet_data[0])  # Skip the first header row

# Load spaCy and pytextrank
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("textrank")

def extract_keywords(text):
    doc = nlp(text)
    keywords = [phrase.text for phrase in doc._.phrases[:5]]  # Extract top 5 key phrases
    return ", ".join(keywords)

def fetch_news(query):
    googlenews = GoogleNews()
    googlenews.search(query)
    result = googlenews.result()

    news_list = []
    for item in result:
        title = item['title']
        date = item['date']
        desc = item['desc']
        link = item['link']
        keywords = extract_keywords(desc)
        news_list.append([title, date, desc, link, keywords])

    return news_list

def add_sheet(query, data):
    date_str = datetime.now().strftime('%Y-%m-%d')
    new_sheet_name = f"{query}&{date_str}"
    try:
        worksheet = gsheets.add_worksheet(title=new_sheet_name, rows=data.shape[0]+1, cols=data.shape[1])
        worksheet.update([data.columns.values.tolist()] + data.values.tolist())
    except gspread.exceptions.APIError as e:
        print(f"Error adding worksheet: {e}")

def display_data(query):
    if query:
        news_results = fetch_news(query)
        if news_results:
            filtered_df = pd.DataFrame(news_results, columns=['標題', '日期', '描述', '連結', '關鍵字'])
            add_sheet(query, filtered_df)
            return filtered_df
    return pd.DataFrame(columns=['標題', '日期', '描述', '連結', '關鍵字'])

def summarize_news(news_df):
    descriptions = news_df['描述'].tolist()
    text = ". ".join(descriptions)
    sentences = text.split(".")
    summary_sentences = sentences[:3]
    summary = ". ".join(summary_sentences)

    summarizer = pipeline("summarization", model="pszemraj/led-large-book-summary")
    out_str = summarizer(summary, max_length=512, min_length=30, do_sample=False)

    summary_text = out_str[0]['summary_text']

    # Create a new DataFrame with the summary result
    summary_df = pd.DataFrame({'摘要': [summary_text]})
    add_sheet("摘要", summary_df)

    return summary_text

def display_summary(query):
    news_df = display_data(query)
    if not news_df.empty:
        return summarize_news(news_df)
    return "No news found to summarize."

with gr.Blocks() as demo:
    gr.Markdown("<h1 style='text-align: center;'>專題報告_與論節錄</h1>")

    with gr.TabItem("作業5"):
        gr.Markdown("請輸入您本次想要在 Google News 查閱的文章關鍵字")
        query_input = gr.Textbox(placeholder="請輸入關鍵字")
        display_button = gr.Button("送出")
        data_table = gr.DataFrame(label="資料表")

        # 設置按鈕點擊事件
        display_button.click(fn=display_data, inputs=query_input, outputs=data_table)

    with gr.TabItem("摘要結果"):
        summary_button = gr.Button("生成摘要")
        summary_output = gr.Textbox(label="摘要結果")

        # 設置按鈕點擊事件
        summary_button.click(fn=display_summary, inputs=query_input, outputs=summary_output)

demo.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://61a0dc2985bccca3e1.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://61a0dc2985bccca3e1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# #新增情意分析(原內容)

# %% [markdown]
# #輿情分析

# %%
from collections import defaultdict
from transformers import pipeline

# Load the sentiment analysis model
classifier = pipeline("text-classification", model="distilbert-base-uncased-finetuned-sst-2-english")

def fetch_news(query):
    googlenews = GoogleNews()
    googlenews.search(query)
    result = googlenews.result()

    news_list = []
    for item in result:
        title = item['title']
        date = item['date']
        desc = item['desc']
        link = item['link']
        keywords = extract_keywords(desc)

        # Perform sentiment analysis on the description
        sentiment_result = classifier(desc)
        sentiment_score = sentiment_result[0]['score'] if sentiment_result else 0
        sentiment_label = sentiment_result[0]['label'] if sentiment_result else 'NEUTRAL'

        # Append the sentiment score and label to the news item
        news_list.append([title, date, desc, link, keywords, sentiment_score, sentiment_label])

    return news_list

# Update the DataFrame construction to include the new sentiment columns
def display_data(query):
    if query:
        news_results = fetch_news(query)
        if news_results:
            filtered_df = pd.DataFrame(news_results, columns=['標題', '日期', '描述', '連結', '關鍵字', '輿情評分', '情感標籤'])
            add_sheet(query, filtered_df)
            return filtered_df
    return pd.DataFrame(columns=['標題', '日期', '描述', '連結', '關鍵字', '輿情評分', '情感標籤'])

# Rest of your code remains unchanged
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
import gspread
import pandas as pd
import gradio as gr
from datetime import datetime
from GoogleNews import GoogleNews
from google.auth import default
import spacy
import pytextrank
from transformers import pipeline

# Authenticate with Google Sheets
creds, _ = default()
gc = gspread.authorize(creds)

# Initialize the connection to Google Sheets
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1NEts6y1L2VQE6pBM7f4GRWeP0mdFQKanIJiFDPBcrRs/edit?usp=sharing'
gsheets = gc.open_by_url(spreadsheet_url)
sheet_data = gsheets.worksheet('作業5(導入)').get_all_values()

# Convert the data to a DataFrame
df = pd.DataFrame(sheet_data[1:], columns=sheet_data[0])  # Skip the first header row

# Load spaCy and pytextrank
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("textrank")

def extract_keywords(text):
    doc = nlp(text)
    keywords = [phrase.text for phrase in doc._.phrases[:5]]  # Extract top 5 key phrases
    return ", ".join(keywords)

from collections import defaultdict
from transformers import pipeline

# Load the sentiment analysis model
classifier = pipeline("text-classification", model="distilbert-base-uncased-finetuned-sst-2-english")

def fetch_news(query):
    googlenews = GoogleNews()
    googlenews.search(query)
    result = googlenews.result()

    news_list = []
    for item in result:
        title = item['title']
        date = item['date']
        desc = item['desc']
        link = item['link']
        keywords = extract_keywords(desc)

        # Perform sentiment analysis on the description
        sentiment_result = classifier(desc)
        sentiment_score = sentiment_result[0]['score'] if sentiment_result else 0
        sentiment_label = sentiment_result[0]['label'] if sentiment_result else 'NEUTRAL'

        # Append the sentiment score and label to the news item
        news_list.append([title, date, desc, link, keywords, sentiment_score, sentiment_label])

    return news_list

# Update the DataFrame construction to include the new sentiment columns
def display_data(query):
    if query:
        news_results = fetch_news(query)
        if news_results:
            filtered_df = pd.DataFrame(news_results, columns=['標題', '日期', '描述', '連結', '關鍵字', '輿情評分', '情感標籤'])
            add_sheet(query, filtered_df)
            return filtered_df
    return pd.DataFrame(columns=['標題', '日期', '描述', '連結', '關鍵字', '輿情評分', '情感標籤'])

# Define a function to apply a style to non-positive rows
def highlight_non_positive(row):
    return ['background-color: yellow' if val == 'NEGATIVE' else '' for val in row]

# Rest of your code remains unchanged

def summarize_news(news_df):
    descriptions = news_df['描述'].tolist()
    text = ". ".join(descriptions)
    sentences = text.split(".")
    summary_sentences = sentences[:3]
    summary = ". ".join(summary_sentences)

    summarizer = pipeline("summarization", model="pszemraj/led-large-book-summary")
    out_str = summarizer(summary, max_length=512, min_length=30, do_sample=False)

    summary_text = out_str[0]['summary_text']

    # Create a new DataFrame with the summary result
    summary_df = pd.DataFrame({'摘要': [summary_text]})
    add_sheet("摘要", summary_df)

    return summary_text

def display_summary(query):
    news_df = display_data(query)
    if not news_df.empty:
        return summarize_news(news_df)
    return "No news found to summarize."

with gr.Blocks() as demo:
    gr.Markdown("<h1 style='text-align: center;'>專題報告_與論節錄</h1>")

    with gr.TabItem("作業5"):
        gr.Markdown("請輸入您本次想要在 Google News 查閱的文章關鍵字")
        query_input = gr.Textbox(placeholder="請輸入關鍵字")
        display_button = gr.Button("送出")
        data_table = gr.DataFrame(label="資料表")

        # 設置按鈕點擊事件
        display_button.click(fn=display_data, inputs=query_input, outputs=data_table)

    with gr.TabItem("摘要結果"):
        summary_button = gr.Button("生成摘要")
        summary_output = gr.Textbox(label="摘要結果")

        # 設置按鈕點擊事件
        summary_button.click(fn=display_summary, inputs=query_input, outputs=summary_output)

demo.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://07e996b29b578a2d06.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://07e996b29b578a2d06.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# #標示出非正向的列內容

# %%
import gspread
import pandas as pd
import gradio as gr
from datetime import datetime
from GoogleNews import GoogleNews
from google.auth import default
import spacy
import pytextrank
from transformers import pipeline

# Authenticate with Google Sheets
creds, _ = default()
gc = gspread.authorize(creds)

# Initialize the connection to Google Sheets
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1NEts6y1L2VQE6pBM7f4GRWeP0mdFQKanIJiFDPBcrRs/edit?usp=sharing'
gsheets = gc.open_by_url(spreadsheet_url)
sheet_data = gsheets.worksheet('作業5(導入)').get_all_values()

# Convert the data to a DataFrame
df = pd.DataFrame(sheet_data[1:], columns=sheet_data[0])  # Skip the first header row

# Load spaCy and pytextrank
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("textrank")

def extract_keywords(text):
    doc = nlp(text)
    keywords = [phrase.text for phrase in doc._.phrases[:5]]  # Extract top 5 key phrases
    return ", ".join(keywords)

from collections import defaultdict
from transformers import pipeline

# Load the sentiment analysis model
classifier = pipeline("text-classification", model="distilbert-base-uncased-finetuned-sst-2-english")

def fetch_news(query):
    googlenews = GoogleNews()
    googlenews.search(query)
    result = googlenews.result()

    news_list = []
    for item in result:
        title = item['title']
        date = item['date']
        desc = item['desc']
        link = item['link']
        keywords = extract_keywords(desc)

        # Perform sentiment analysis on the description
        sentiment_result = classifier(desc)
        sentiment_score = sentiment_result[0]['score'] if sentiment_result else 0
        sentiment_label = sentiment_result[0]['label'] if sentiment_result else 'NEUTRAL'

        # Append the sentiment score and label to the news item
        news_list.append([title, date, desc, link, keywords, sentiment_score, sentiment_label])

    return news_list

# Update the DataFrame construction to include the new sentiment columns
def display_data(query):
    if query:
        news_results = fetch_news(query)
        if news_results:
            filtered_df = pd.DataFrame(news_results, columns=['標題', '日期', '描述', '連結', '關鍵字', '輿情評分', '情感標籤'])
            add_sheet(query, filtered_df)

            # Convert DataFrame to HTML and apply highlighting to non-positive sentiment rows
            styled_html = filtered_df.style.applymap(lambda val: 'background-color: yellow' if val == 'NEGATIVE' else '').render()
            return styled_html
    return ""

# Update Gradio interface to display the HTML representation of the DataFrame
with gr.Blocks() as demo:
    # ... other parts of your Gradio interface ...

    with gr.TabItem("作業5"):
        # ... other parts of your Gradio interface ...
        data_table = gr.HTML(label="資料表")

        # Update the button click event to display the HTML representation
        display_button.click(fn=display_data, inputs=query_input, outputs=data_table)

# ... rest of your Gradio code ...


# Define a function to apply a style to non-positive rows
def highlight_non_positive(row):
    return ['background-color: yellow' if val == 'NEGATIVE' else '' for val in row]

# Modify the display_data function to apply the highlight
def summarize_news(news_df):
    descriptions = news_df['描述'].tolist()
    text = ". ".join(descriptions)
    sentences = text.split(".")
    summary_sentences = sentences[:3]
    summary = ". ".join(summary_sentences)

    summarizer = pipeline("summarization", model="pszemraj/led-large-book-summary")
    out_str = summarizer(summary, max_length=512, min_length=30, do_sample=False)

    summary_text = out_str[0]['summary_text']

    # Create a new DataFrame with the summary result
    summary_df = pd.DataFrame({'摘要': [summary_text]})
    add_sheet("摘要", summary_df)

    return summary_text

def display_summary(query):
    news_df = display_data(query)
    if not news_df.empty:
        return summarize_news(news_df)
    return "No news found to summarize."

with gr.Blocks() as demo:
    gr.Markdown("<h1 style='text-align: center;'>專題報告_與論節錄</h1>")

    with gr.TabItem("作業5"):
        gr.Markdown("請輸入您本次想要在 Google News 查閱的文章關鍵字")
        query_input = gr.Textbox(placeholder="請輸入關鍵字")
        display_button = gr.Button("送出")
        data_table = gr.DataFrame(label="資料表")

        # 設置按鈕點擊事件
        display_button.click(fn=display_data, inputs=query_input, outputs=data_table)

    with gr.TabItem("摘要結果"):
        summary_button = gr.Button("生成摘要")
        summary_output = gr.Textbox(label="摘要結果")

        # 設置按鈕點擊事件
        summary_button.click(fn=display_summary, inputs=query_input, outputs=summary_output)

demo.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://7ac216a7bd9995163f.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://7ac216a7bd9995163f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# #舊檔

# %% [markdown]
# ## highligh negitive

# %%
import gspread
import pandas as pd
import gradio as gr
from datetime import datetime
from GoogleNews import GoogleNews
from google.auth import default
import spacy
import pytextrank
from transformers import pipeline

# Authenticate with Google Sheets
creds, _ = default()
gc = gspread.authorize(creds)

# Initialize the connection to Google Sheets
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1NEts6y1L2VQE6pBM7f4GRWeP0mdFQKanIJiFDPBcrRs/edit?usp=sharing'
gsheets = gc.open_by_url(spreadsheet_url)
sheet_data = gsheets.worksheet('作業5(導入)').get_all_values()

# Convert the data to a DataFrame
df = pd.DataFrame(sheet_data[1:], columns=sheet_data[0])  # Skip the first header row

# Load spaCy and pytextrank
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("textrank")

def extract_keywords(text):
    doc = nlp(text)
    keywords = [phrase.text for phrase in doc._.phrases[:5]]  # Extract top 5 key phrases
    return ", ".join(keywords)

from collections import defaultdict
from transformers import pipeline

# Load the sentiment analysis model
classifier = pipeline("text-classification", model="distilbert-base-uncased-finetuned-sst-2-english")

def fetch_news(query):
    googlenews = GoogleNews()
    googlenews.search(query)
    result = googlenews.result()

    news_list = []
    for item in result:
        title = item['title']
        date = item['date']
        desc = item['desc']
        link = item['link']
        keywords = extract_keywords(desc)

        # Perform sentiment analysis on the description
        sentiment_result = classifier(desc)
        sentiment_score = sentiment_result[0]['score'] if sentiment_result else 0
        sentiment_label = sentiment_result[0]['label'] if sentiment_result else 'NEUTRAL'

        # Append the sentiment score and label to the news item
        news_list.append([title, date, desc, link, keywords, sentiment_score, sentiment_label])

    return news_list

# Update the DataFrame construction to include the new sentiment columns
def display_data(query):
    if query:
        news_results = fetch_news(query)
        if news_results:
            filtered_df = pd.DataFrame(news_results, columns=['標題', '日期', '描述', '連結', '關鍵字', '輿情評分', '情感標籤'])
            add_sheet(query, filtered_df)
            return filtered_df
    return pd.DataFrame(columns=['標題', '日期', '描述', '連結', '關鍵字', '輿情評分', '情感標籤'])

# Rest of your code remains unchanged

def summarize_news(news_df):
    descriptions = news_df['描述'].tolist()
    text = ". ".join(descriptions)
    sentences = text.split(".")
    summary_sentences = sentences[:3]
    summary = ". ".join(summary_sentences)

    summarizer = pipeline("summarization", model="pszemraj/led-large-book-summary")
    out_str = summarizer(summary, max_length=512, min_length=30, do_sample=False)

    summary_text = out_str[0]['summary_text']

    # Create a new DataFrame with the summary result
    summary_df = pd.DataFrame({'摘要': [summary_text]})
    add_sheet("摘要", summary_df)

    return summary_text


# Update Gradio interface to display the styled DataFrame
with gr.Blocks() as demo:
    # ... other parts of your Gradio interface ...

    with gr.TabItem("作業5"):
        # ... other parts of your Gradio interface ...
        data_table = gr.DataFrame(label="資料表")

        # Update the button click event to display the styled DataFrame
        display_button.click(fn=display_data, inputs=query_input, outputs=data_table)

# ... rest of your Gradio code ...

def display_summary(query):
    try:
        news_df = display_data(query)
        if not news_df.empty:
            return summarize_news(news_df)
        else:
            return "No news found to summarize."
    except Exception as e:
        # Return a warning message if an error occurs
        return f"Warning: An error occurred. {str(e)}"

with gr.Blocks() as demo:
    gr.Markdown("<h1 style='text-align: center;'>專題報告_與論節錄</h1>")

    with gr.TabItem("作業5"):
        gr.Markdown("請輸入您本次想要在 Google News 查閱的文章關鍵字")
        query_input = gr.Textbox(placeholder="請輸入關鍵字")
        display_button = gr.Button("送出")
        data_table = gr.DataFrame(label="資料表")

        # 設置按鈕點擊事件
        display_button.click(fn=display_data, inputs=query_input, outputs=data_table)

    with gr.TabItem("摘要結果"):
        summary_button = gr.Button("生成摘要")
        summary_output = gr.Textbox(label="摘要結果")

        # 設置按鈕點擊事件
        summary_button.click(fn=display_summary, inputs=query_input, outputs=summary_output)

demo.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://99922ccfab79379b7b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://99922ccfab79379b7b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # RAG文本查詢

# %%
! pip install -q -U pypdf faiss-cpu
! pip install -q -U InstructorEmbedding
! pip install huggingface_hub -q

# %%
! pip install googletrans
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 3.0 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15718 sha256=da76f6a7bc9aaea474e9ea22422b6bc654611021aeb54aa66b471eb3c87e2ed7
#   Stored in directory: /root/.cache/pip/wheels/b3/81/ea/8b030407f8ebfc2f857814e086bb22ca2d4fea1a7be63652ab
# Successfully built googletrans
# ...
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
# ...

# %%
! pip install gradio -q
# Out:
# ERROR: Operation cancelled by user

# %%
! pip install langchain==0.1.2
! pip install sentence_transformers==2.2.2

# %%
import os
import glob
import textwrap
import time

# %%
import langchain

# %%
from langchain.document_loaders import PyPDFLoader

# %%
from langchain.document_loaders import DirectoryLoader

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
from langchain import PromptTemplate, LLMChain

# %%
from langchain.llms import HuggingFacePipeline

# %%
from InstructorEmbedding import INSTRUCTOR
# Out:
# /usr/local/lib/python3.10/dist-packages/InstructorEmbedding/instructor.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import trange

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings

# %%
from langchain.chains import RetrievalQA

# %%
import torch

# %%
from langchain.vectorstores import FAISS

# %%
class CFG:
    model_name = 'mistralai/Mistral-7B-Instruct-v0.1'
    temperature = 0.5
    top_p = 0.95
    repetition_penalty = 1.15
    do_sample = True
    max_new_tokens = 400
    num_return_sequences=1

    split_chunk_size = 800
    split_overlap = 0

    embeddings_model_repo = 'sentence-transformers/all-MiniLM-L6-v2'

    k = 3

    PDFs_path = 'C:\\Users\\123\\Desktop\\net_learning'
    Embeddings_path =  './faiss_index_py'

# %%
import gspread
import pandas as pd
from google.auth import default
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

class CFG:
    model_name = 'mistralai/Mistral-7B-Instruct-v0.1'
    temperature = 0.5
    top_p = 0.95
    repetition_penalty = 1.15
    do_sample = True
    max_new_tokens = 400
    num_return_sequences=1

    split_chunk_size = 800
    split_overlap = 0

    embeddings_model_repo = 'sentence-transformers/all-MiniLM-L6-v2'

    k = 3

    PDFs_path = 'C:\\Users\\123\\Desktop\\net_learning'
    Embeddings_path =  './faiss_index_py'

# Authenticate with Google Sheets
creds, _ = default()
gc = gspread.authorize(creds)

# Fetch data from Google Sheets
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1NEts6y1L2VQE6pBM7f4GRWeP0mdFQKanIJiFDPBcrRs/edit?usp=sharing'
gsheets = gc.open_by_url(spreadsheet_url)
sheet = gsheets.worksheet('作業5(導入)').get_all_values()

# Convert the data to a DataFrame
df = pd.DataFrame(sheet[1:], columns=sheet[0])

# Load the pre-trained embeddings model
model = SentenceTransformer(CFG.embeddings_model_repo)

# Preprocess the data: Extract the '描述' column
texts = df['描述'].tolist()

# Generate embeddings for the text data
embeddings = model.encode(texts)

# Initialize FAISS index
embedding_dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(embedding_dimension)

# Add embeddings to the FAISS index
index.add(embeddings)

# Save the FAISS index to disk
faiss.write_index(index, CFG.Embeddings_path)

print(f"Embeddings have been successfully added to the FAISS index and saved to {CFG.Embeddings_path}")
# Out:
# Embeddings have been successfully added to the FAISS index and saved to ./faiss_index_py

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# %%
from langchain.llms import HuggingFaceHub

llm = HuggingFaceHub(
    repo_id = CFG.model_name,
    model_kwargs={
        "max_new_tokens": CFG.max_new_tokens,
        "temperature": CFG.temperature,
        "top_p": CFG.top_p,
        "repetition_penalty": CFG.repetition_penalty,
        "do_sample": CFG.do_sample,
        "num_return_sequences": CFG.num_return_sequences
    }
)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     303     try:
# --> 304         response.raise_for_status()
#     305     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 403 Client Error: Forbidden for url: https://huggingface.co/api/models/mistralai/Mistral-7B-Instruct-v0.1
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# <ipython-input-20-cc0453276430> in <cell line: 3>()
#       1 from langchain.llms import HuggingFaceHub
#       2
# ...

# %% [markdown]
# #最終報告用版本

# %%
import gspread
import pandas as pd
import gradio as gr
from datetime import datetime
from GoogleNews import GoogleNews
from google.auth import default
import spacy
import pytextrank
from transformers import pipeline

# Authenticate with Google Sheets
creds, _ = default()
gc = gspread.authorize(creds)

# Initialize the connection to Google Sheets
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1NEts6y1L2VQE6pBM7f4GRWeP0mdFQKanIJiFDPBcrRs/edit?usp=sharing'
gsheets = gc.open_by_url(spreadsheet_url)
sheet_data = gsheets.worksheet('作業5(導入)').get_all_values()

# Convert the data to a DataFrame
df = pd.DataFrame(sheet_data[1:], columns=sheet_data[0])  # Skip the first header row

# Load spaCy and pytextrank
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("textrank")

def extract_keywords(text):
    doc = nlp(text)
    keywords = [phrase.text for phrase in doc._.phrases[:5]]  # Extract top 5 key phrases
    return ", ".join(keywords)

# Load the sentiment analysis model
classifier = pipeline("text-classification", model="distilbert-base-uncased-finetuned-sst-2-english")

def fetch_news(query):
    googlenews = GoogleNews()
    googlenews.search(query)
    result = googlenews.result()

    news_list = []
    for item in result:
        title = item['title']
        date = item['date']
        desc = item['desc']
        link = item['link']
        keywords = extract_keywords(desc)

        # Perform sentiment analysis on the description
        sentiment_result = classifier(desc)
        sentiment_score = sentiment_result[0]['score'] if sentiment_result else 0
        sentiment_label = sentiment_result[0]['label'] if sentiment_result else 'NEUTRAL'

        # Append the sentiment score and label to the news item
        news_list.append([title, date, desc, link, keywords, sentiment_score, sentiment_label])

    return news_list

# Update the DataFrame construction to include the new sentiment columns
def display_data(query):
    if query:
        news_results = fetch_news(query)
        if news_results:
            filtered_df = pd.DataFrame(news_results, columns=['標題', '日期', '描述', '連結', '關鍵字', '輿情評分', '情感標籤'])
            add_sheet(query, filtered_df)
            return filtered_df
    return pd.DataFrame(columns=['標題', '日期', '描述', '連結', '關鍵字', '輿情評分', '情感標籤'])

def add_sheet(query, data):
    date_str = datetime.now().strftime('%Y-%m-%d')
    new_sheet_name = f"{query}&{date_str}"
    try:
        worksheet = gsheets.add_worksheet(title=new_sheet_name, rows=data.shape[0]+1, cols=data.shape[1])
        worksheet.update([data.columns.values.tolist()] + data.values.tolist())
    except gspread.exceptions.APIError as e:
        print(f"Error adding worksheet: {e}")

def summarize_news(news_df):
    descriptions = news_df['描述'].tolist()
    text = ". ".join(descriptions)
    sentences = text.split(".")
    summary_sentences = sentences[:3]
    summary = ". ".join(summary_sentences)

    summarizer = pipeline("summarization", model="pszemraj/led-large-book-summary")
    out_str = summarizer(summary, max_length=512, min_length=30, do_sample=False)

    summary_text = out_str[0]['summary_text']

    # Create a new DataFrame with the summary result
    summary_df = pd.DataFrame({'摘要': [summary_text]})
    add_sheet("摘要", summary_df)

    return summary_text

def display_summary(query):
    news_df = display_data(query)
    if not news_df.empty:
        return summarize_news(news_df)
    return "No news found to summarize."

def get_previous_queries():
    worksheet_list = gsheets.worksheets()
    query_list = []
    for worksheet in worksheet_list:
        if '&' in worksheet.title:
            query = worksheet.title.split('&')[0]
            query_list.append(query)
    return query_list

def fetch_previous_data(query):
    worksheet_list = gsheets.worksheets()
    for worksheet in worksheet_list:
        if worksheet.title.startswith(query):
            sheet_data = worksheet.get_all_values()
            return pd.DataFrame(sheet_data[1:], columns=sheet_data[0])
    return pd.DataFrame()

def search_all_data(keyword):
    data = []
    for worksheet in gsheets.worksheets():
        sheet_data = worksheet.get_all_values()
        df = pd.DataFrame(sheet_data[1:], columns=sheet_data[0])
        filtered_df = df[df.apply(lambda row: row.astype(str).str.contains(keyword).any(), axis=1)]
        data.append(filtered_df)
    if data:
        combined_df = pd.concat(data, ignore_index=True)
        return combined_df
    return pd.DataFrame()

with gr.Blocks() as demo:
    gr.Markdown("<h1 style='text-align: center;'>專題報告_與論節錄</h1>")

    with gr.TabItem("查詢線上文章"):
        gr.Markdown("請輸入您本次想要在 Google News 查閱的文章關鍵字")
        query_input = gr.Textbox(placeholder="請輸入關鍵字")
        display_button = gr.Button("送出")
        data_table = gr.DataFrame(label="資料表")

        # 設置按鈕點擊事件
        display_button.click(fn=display_data, inputs=query_input, outputs=data_table)

    with gr.TabItem("摘要結果"):
        summary_button = gr.Button("生成摘要")
        summary_output = gr.Textbox(label="摘要結果")

        # 設置按鈕點擊事件
        summary_button.click(fn=display_summary, inputs=query_input, outputs=summary_output)

    with gr.TabItem("歷史查詢"):
        previous_queries = get_previous_queries()
        query_dropdown = gr.Dropdown(choices=previous_queries, label="選擇歷史查詢關鍵字")
        previous_data_button = gr.Button("查詢")
        previous_data_table = gr.DataFrame(label="歷史資料表")

        # 設置按鈕點擊事件
        previous_data_button.click(fn=fetch_previous_data, inputs=query_dropdown, outputs=previous_data_table)

    with gr.TabItem("文章搜尋"):
        search_input = gr.Textbox(placeholder="請輸入搜尋關鍵字")
        search_button = gr.Button("搜尋")
        search_result_table = gr.DataFrame(label="搜尋結果")

        # 設置按鈕點擊事件
        search_button.click(fn=search_all_data, inputs=search_input, outputs=search_result_table)

demo.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://12c5f5d13f5cfdb899.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://12c5f5d13f5cfdb899.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ##歷史查詢功能

# %%
import gspread
import pandas as pd
import gradio as gr
from datetime import datetime
from GoogleNews import GoogleNews
from google.auth import default
import spacy
import pytextrank
from transformers import pipeline

# Authenticate with Google Sheets
creds, _ = default()
gc = gspread.authorize(creds)

# Initialize the connection to Google Sheets
spreadsheet_url = 'https://docs.google.com/spreadsheets/d/1NEts6y1L2VQE6pBM7f4GRWeP0mdFQKanIJiFDPBcrRs/edit?usp=sharing'
gsheets = gc.open_by_url(spreadsheet_url)
sheet_data = gsheets.worksheet('作業5(導入)').get_all_values()

# Convert the data to a DataFrame
df = pd.DataFrame(sheet_data[1:], columns=sheet_data[0])  # Skip the first header row

# Load spaCy and pytextrank
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("textrank")

def extract_keywords(text):
    doc = nlp(text)
    keywords = [phrase.text for phrase in doc._.phrases[:5]]  # Extract top 5 key phrases
    return ", ".join(keywords)

from collections import defaultdict
from transformers import pipeline

# Load the sentiment analysis model
classifier = pipeline("text-classification", model="distilbert-base-uncased-finetuned-sst-2-english")

def fetch_news(query):
    googlenews = GoogleNews()
    googlenews.search(query)
    result = googlenews.result()

    news_list = []
    for item in result:
        title = item['title']
        date = item['date']
        desc = item['desc']
        link = item['link']
        keywords = extract_keywords(desc)

        # Perform sentiment analysis on the description
        sentiment_result = classifier(desc)
        sentiment_score = sentiment_result[0]['score'] if sentiment_result else 0
        sentiment_label = sentiment_result[0]['label'] if sentiment_result else 'NEUTRAL'

        # Append the sentiment score and label to the news item
        news_list.append([title, date, desc, link, keywords, sentiment_score, sentiment_label])

    return news_list

# Update the DataFrame construction to include the new sentiment columns
def display_data(query):
    if query:
        news_results = fetch_news(query)
        if news_results:
            filtered_df = pd.DataFrame(news_results, columns=['標題', '日期', '描述', '連結', '關鍵字', '輿情評分', '情感標籤'])
            add_sheet(query, filtered_df)
            return filtered_df
    return pd.DataFrame(columns=['標題', '日期', '描述', '連結', '關鍵字', '輿情評分', '情感標籤'])

# Define a function to apply a style to non-positive rows
def highlight_non_positive(row):
    return ['background-color: yellow' if val == 'NEGATIVE' else '' for val in row]

def add_sheet(query, data):
    date_str = datetime.now().strftime('%Y-%m-%d')
    new_sheet_name = f"{query}&{date_str}"
    try:
        worksheet = gsheets.add_worksheet(title=new_sheet_name, rows=data.shape[0]+1, cols=data.shape[1])
        worksheet.update([data.columns.values.tolist()] + data.values.tolist())
    except gspread.exceptions.APIError as e:
        print(f"Error adding worksheet: {e}")

def summarize_news(news_df):
    descriptions = news_df['描述'].tolist()
    text = ". ".join(descriptions)
    sentences = text.split(".")
    summary_sentences = sentences[:3]
    summary = ". ".join(summary_sentences)

    summarizer = pipeline("summarization", model="pszemraj/led-large-book-summary")
    out_str = summarizer(summary, max_length=512, min_length=30, do_sample=False)

    summary_text = out_str[0]['summary_text']

    # Create a new DataFrame with the summary result
    summary_df = pd.DataFrame({'摘要': [summary_text]})
    add_sheet("摘要", summary_df)

    return summary_text

def display_summary(query):
    news_df = display_data(query)
    if not news_df.empty:
        return summarize_news(news_df)
    return "No news found to summarize."

def get_previous_queries():
    worksheet_list = gsheets.worksheets()
    query_list = []
    for worksheet in worksheet_list:
        if '&' in worksheet.title:
            query = worksheet.title.split('&')[0]
            query_list.append(query)
    return query_list

def fetch_previous_data(query):
    worksheet_list = gsheets.worksheets()
    for worksheet in worksheet_list:
        if worksheet.title.startswith(query):
            sheet_data = worksheet.get_all_values()
            return pd.DataFrame(sheet_data[1:], columns=sheet_data[0])
    return pd.DataFrame()

with gr.Blocks() as demo:
    gr.Markdown("<h1 style='text-align: center;'>專題報告_與論節錄</h1>")

    with gr.TabItem("作業5"):
        gr.Markdown("請輸入您本次想要在 Google News 查閱的文章關鍵字")
        query_input = gr.Textbox(placeholder="請輸入關鍵字")
        display_button = gr.Button("送出")
        data_table = gr.DataFrame(label="資料表")

        # 設置按鈕點擊事件
        display_button.click(fn=display_data, inputs=query_input, outputs=data_table)

    with gr.TabItem("摘要結果"):
        summary_button = gr.Button("生成摘要")
        summary_output = gr.Textbox(label="摘要結果")

        # 設置按鈕點擊事件
        summary_button.click(fn=display_summary, inputs=query_input, outputs=summary_output)

    with gr.TabItem("歷史查詢"):
        previous_queries = get_previous_queries()
        query_dropdown = gr.Dropdown(choices=previous_queries, label="選擇歷史查詢關鍵字")
        previous_data_button = gr.Button("查詢")
        previous_data_table = gr.DataFrame(label="歷史資料表")

        # 設置按鈕點擊事件
        previous_data_button.click(fn=fetch_previous_data, inputs=query_dropdown, outputs=previous_data_table)

demo.launch()
# Out:
# /usr/local/lib/python3.10/dist-packages
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://77110ed66cb2a27ebf.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://77110ed66cb2a27ebf.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
