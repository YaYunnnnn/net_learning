# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("C:/Users/123/Downloads/adult.csv")

selected_column = df['Income']

plt.hist(selected_column, bins=10, edgecolor='black')

plt.xlabel('income')
plt.ylabel('freq')
plt.title('data')

plt.show()
